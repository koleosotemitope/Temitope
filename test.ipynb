# %%
pip install pandas numpy
# Out:
# ...
#      ---------------------------------------- 9.9/9.9 MB 8.0 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 12.6/12.6 MB 7.4 MB/s eta 0:00:00
# ...
#      ------------------------------------- 349.0/349.0 kB 10.9 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The scripts f2py.exe and numpy-config.exe are installed in 'c:\Users\koleo\AppData\Local\Programs\Python\Python311\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#
# [notice] A new release of pip available: 22.3.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
